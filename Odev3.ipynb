# %%
import time
isim = input("İsminiz Nedir? ")

print ("Hosgeldin " + isim, " adam asmaca oynayalım.")

print (" ")

time.sleep(1)

print ("Tahmin et")
time.sleep(0.5)

kelime = "güvenlik"

tahmin = ''

hak = 10


while hak > 0:         

    failed = 0             
    
    for i in kelime:      

    
        if i in tahmin:    
    
        
            print(i)    

        else:
            print ("_")     
       
            failed += 1    
    
    if failed == 0:        
        print ("Sen Kazandın")  
        break              

    tahmn = input("Karakter tahmin et:") 

    tahmin += tahmn                    

    if tahmn not in kelime:  
 
     
        hak -= 1        
 
   
        print("Yanlış")    
 
    
        print ("Bu kadar hakkınız", + hak, 'kaldı.')
    
        if hak == 0:           

            print ("Kaybettiniz.")
# Out:
# İsminiz Nedir? Ekrem Samil
# Hosgeldin Ekrem Samil  adam asmaca oynayalım.
#
# Tahmin et
# _
# _
# _
# _
# _
# _
# _
# _
# Karakter tahmin et:a
# Yanlış
# Bu kadar hakkınız 9 kaldı.
# _
# _
# _
# _
# _
# _
# _
# _
# Karakter tahmin et:g
# g
# _
# _
# _
# _
# _
# _
# _
# Karakter tahmin et:ü
# g
# ü
# _
# _
# _
# _
# _
# _
# Karakter tahmin et:v
# g
# ü
# v
# _
# _
# _
# _
# _
# Karakter tahmin et:e
# g
# ü
# v
# e
# _
# _
# _
# _
# Karakter tahmin et:n
# g
# ü
# v
# e
# n
# _
# _
# _
# Karakter tahmin et:l
# g
# ü
# v
# e
# n
# l
# _
# _
# Karakter tahmin et:i
# g
# ü
# v
# e
# n
# l
# i
# _
# Karakter tahmin et:k
# g
# ü
# v
# e
# n
# l
# i
# k
# Sen Kazandın
