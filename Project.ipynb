# %%
sys_kullanıcı_adı ="ekrem"
sys_parola ="12345"
kullanıcı_adı = input("Kullanıcı Adı:")
parola = input("Parola:")           
ders_liste = ["Matematik,İngilizce,Ağ Temelleri,Programlama Temelleri,Web Tasarım"] 
ders_secim = []
not_sözlük= {}    
## Kullanıcı Girişi   
if (kullanıcı_adı == sys_kullanıcı_adı and sys_parola != parola):
    print("Parola Hatalı.")
elif (kullanıcı_adı != sys_kullanıcı_adı and parola == sys_parola):
    print ("Kullanıcı Adı Hatalı.")
elif (kullanıcı_adı != sys_kullanıcı_adı and parola != sys_parola):
    print("Kullanıcı adı ve Parola Hatalı..")
else:
    print("Hoşgeldin {} ".format(sys_kullanıcı_adı)

#Not
midterm = 0
final = 0 
project = 0 

not_ortalama = midterm*3/10 + final*5/10 + project*2/10

if (not_ortalama > 90):
    print("AA")
elif (50 < not_ortalama < 70):
    print("CC")
elif (30 < not_ortalama < 50):
    print("DD")
elif (0 < not_ortalama < 30):
    print("FF")
    print("Kaldınız")
elif (q == break):
    print("Çıkmak için 'q'ya basınız")
else:
    print("Geçerli Bir Not giriniz ")



print("Lütfen en az 3 en fazla 5 ders seçiniz.Ve notlarınızı giriniz...)

print("1. Matematik")

print("2.İngilizce")

print("3.Ağ Temelleri")

print("4.Programlama Temelleri")

print("5.Web Tasarım")

print("Çıkış İçin 'q' ya basınız.")
      
while True:
    işlem = input("Dersi Seçiniz ")
    
    if (işlem == 1):
        print("Matematik Seçildi Ders Notlarınızı Giriniz:")
        int(input("Midterm Notunuz:",midterm))
        int(input("Final Notunuz : ",final))
        int(input("Project Notunuz : ",project))
        ders_secim.append("Matematik")
        
    elif(işlem ==2):
        print("İngilizce Seçildi Ders Notlarınızı Giriniz:")
        int(input("Midterm Notunuz:",midterm))
        int(input("Final Notunuz : ",final))
        int(input("Project Notunuz : ",project))
        ders_secim.append("İngilizce")
    elif(işlem == 3):
        print("Ağ Temelleri Seçildi Ders Notlarınızı Giriniz:")
        int(input("Midterm Notunuz:",midterm))
        int(input("Final Notunuz : ",final))
        int(input("Project Notunuz : ",project))
        ders_secim.append("Ağ Temelleri")
    elif(işlem == 4):
        print("Programlama Temelleri Seçildi Ders Notlarınızı Giriniz:")
        int(input("Midterm Notunuz:",midterm))
        int(input("Final Notunuz : ",final))
        int(input("Project Notunuz : ",project))
        ders_secim.append("Programlama Temelleri")
    elif(işlem == 5):
        print("Web Tasarım Seçildi Ders Notlarınızı Giriniz:")
        int(input("Midterm Notunuz:",midterm))
        int(input("Final Notunuz : ",final))
        int(input("Project Notunuz : ",project))
        ders_secim.append("Web Tasarım")
    elif(işlem == "q"):
        print("Çıkış Yapılıyor...")
        break
    else:
        print("Geçerli Bir rakam giriniz...")
        

## Başaramadım Üzgünüm
# Out:
#   File "<ipython-input-9-ffd6e71057dd>", line 19
#     print("""
#         ^
# SyntaxError: invalid syntax
